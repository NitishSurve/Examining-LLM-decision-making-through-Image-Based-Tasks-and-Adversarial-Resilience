# %%
import os
from multiprocessing.pool import Pool
from adv_learner_gpt import AdvLearner_gpt
from sim_bandit import sim_bandit_env

from gpt_env import GPT_ENV
#from gemini_env import GeminiImageEnv


from util import DLogger
import sys
# sys.path.append('/tf/')

"""
In this file trained learner in QRL and trained adversary for that QRL are loaded 
and then simulated in the task each 400 times to assess the power of adversary against the trained RNN.

Note that the learner is a trained RNN to provide state and other information to the adversary, 
but the actual environment used for simulations is a Q learning using the same parameters 
used in NC paper.   
"""
# Gemini
#learner_path = 'trained_model/RNN_learner_single/gemini/cells_5_gemini/model-49900.weights_final.h5'
#adv_path = 'trained_model/RNN_learner_single/gemini/cells_5_gemini/model_adv_rnn.h5'

# GPT
learner_path = 'trained_model/RNN_learner_single/cells_5gpt/model-49900.weights_final.h5'
adv_path = 'trained_model/adv_RL_400000_eps_0.01_lr_0.001/gpt/model-248000_final.h5'


def run_sim():
    # try:
    # GPT-3.5
    #output_path = 'evaluate_model/RNN_adv_sim_400000_eps_0.01_lr_0.001/gemini_geminienv/'
    output_path = 'evaluate_model/RNN_adv_sim_400000_eps_0.01_lr_0.001/gpt/'
    # bandit_env = AdvLearner_gpt(learner_path, adv_path, output_path, GPT_ENV(GPT_version='GPT-3.5-turbo-1106'))

    bandit_env = AdvLearner_gpt(
        learner_path,
        adv_path,
        output_path,
        GPT_ENV(
            happy_path='C:/Practicum/Practicum_ Adversarial Decision-making of LLMs-20250513T162528Z-1-001/Final_HN/Final_HN/code_H/image/input_image/happy_face.png',
            sad_path='C:/Practicum/Practicum_ Adversarial Decision-making of LLMs-20250513T162528Z-1-001/Final_HN/Final_HN/code_H/image/input_image/sad_face.png',
            box_image_path='C:/Practicum/Practicum_ Adversarial Decision-making of LLMs-20250513T162528Z-1-001/Final_HN/Final_HN/code_H/image/input_image/box_images_2.png',
            api_key='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'
        )
    )

    # GPT-4
    # output_path = 'evaluate_model/RNN_adv_sim_400000_eps_0.01_lr_0.001/gpt-4-turbo/'
    # bandit_env = AdvLearner_gpt(learner_path, adv_path, output_path, GPT_ENV(GPT_version='GPT-4-turbo'))

    sim_bandit_env(bandit_env, output_path)
    

# def run(f, n_proc):
#     p = Pool(n_proc)
#     p.map(f, range(len(dirs_iter)))
#     p.close()  # no more tasks
#     p.join()  # wrap up current tasks


if __name__ == '__main__':
    # run(run_sim, 40)
    run_sim()
# Out:
# 2025-07-13 00:22:28,328 - ADV - DEBUG - version control: (None, None)
# 2025-07-13 00:22:28,330 - ADV - DEBUG - Learner model loaded from path trained_model/RNN_learner_single/cells_5gpt/model-49900.weights_final.h5
# 2025-07-13 00:22:28,465 - ADV - DEBUG - Adv model loaded from path trained_model/adv_RL_400000_eps_0.01_lr_0.001/gpt/model-248000_final.h5
# 2025-07-13 00:22:28,635 - ADV - DEBUG - version control: (None, None)
# 2025-07-13 00:22:28,636 - ADV - DEBUG - sim 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# ...
